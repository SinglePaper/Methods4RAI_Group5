# %% [markdown]
# # Practical Session on Exploratory Data Analysis for Machine Learning Applications

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# from sklearn import datasets

# %%
# Load the dataset from scikit-learn
# diabetes = datasets.load_diabetes()
data = pd.read_csv("Assignment_dataset.csv")

# %%
data
# Out:
#         ADMISSION  NATURAL_SCIENCE_SCORE  ENGLISH_SCORE  READING_SCORE  \
# 0           False                     49             48             57
# 1           False                     60             55             68
# 2            True                     76             79             68
# 3            True                     73             79             66
# 4           False                     52             56             56
# ...           ...                    ...            ...            ...
# 136873      False                     54             47             48
# 136874      False                     44             35             46
# 136875      False                     43             43             43
# 136876      False                     60             49             71
# 136877      False                     51             45             54
#
#         MATH_SCORE  SOCIAL_SCIENCE_SCORE SCHOOL_CALENDAR  PUBLIC_SCHOOL  \
# 0               25                    48               A           True
# 1               60                    68               A           True
# 2              100                    72               A          False
# 3               83                    72               A          False
# 4               28                    53               A           True
# ...            ...                   ...             ...            ...
# 136873          62                    43               A           True
# 136874          39                    31               A           True
# 136875          12                    46               A           True
# 136876          60                    66               A          False
# 136877          39                    57               A           True
#
#         BILINGUAL_SCHOOL GENDER   AGE PARENTS_EDUCATION FAMILY_INCOME_LEVEL  \
# 0                  False      F  16.0        Vocational                   3
# 1                  False      M  17.0           Primary                   1
# 2                  False      M  17.0        University                   3
# 3                  False      M  17.0        University                   3
# 4                  False      F  15.0           Primary                   1
# ...                  ...    ...   ...               ...                 ...
# 136873             False      M  17.0        Vocational                   3
# 136874             False      F  18.0         Secondary                   2
# 136875             False      M  16.0         Secondary                   1
# 136876             False      M  16.0         Secondary                   2
# 136877             False      F  17.0           Primary                   1
#
#        PEOPLE_AT_HOME  FAMILY_HAS_CAR  HAS_INTERNET_ACCESS
# 0              3 or 4           False                 True
# 1                  7+           False                 True
# 2              3 or 4           False                 True
# 3              3 or 4           False                 True
# 4              3 or 4           False                False
# ...               ...             ...                  ...
# 136873         3 or 4           False                 True
# 136874         3 or 4           False                 True
# 136875         3 or 4           False                 True
# 136876         3 or 4           False                 True
# 136877         3 or 4           False                 True
#
# [136878 rows x 16 columns]

# %%
# 1. Initial Data Exploration:
print(data.head())
print("\nShape of the dataset:", data.shape)
print("\nData types of each column:")
print(data.dtypes)
print("\nMissing values in each column:")
print(data.isnull().sum())
# Out:
#    ADMISSION  NATURAL_SCIENCE_SCORE  ENGLISH_SCORE  READING_SCORE  MATH_SCORE  \
# 0      False                     49             48             57          25
# 1      False                     60             55             68          60
# 2       True                     76             79             68         100
# 3       True                     73             79             66          83
# 4      False                     52             56             56          28
#
#    SOCIAL_SCIENCE_SCORE SCHOOL_CALENDAR  PUBLIC_SCHOOL  BILINGUAL_SCHOOL  \
# 0                    48               A           True             False
# 1                    68               A           True             False
# 2                    72               A          False             False
# 3                    72               A          False             False
# 4                    53               A           True             False
#
#   GENDER   AGE PARENTS_EDUCATION FAMILY_INCOME_LEVEL PEOPLE_AT_HOME  \
# 0      F  16.0        Vocational                   3         3 or 4
# 1      M  17.0           Primary                   1             7+
# 2      M  17.0        University                   3         3 or 4
# 3      M  17.0        University                   3         3 or 4
# 4      F  15.0           Primary                   1         3 or 4
#
#    FAMILY_HAS_CAR  HAS_INTERNET_ACCESS
# 0           False                 True
# 1           False                 True
# 2           False                 True
# 3           False                 True
# 4           False                False
#
# Shape of the dataset: (136878, 16)
#
# Data types of each column:
# ADMISSION                   bool
# NATURAL_SCIENCE_SCORE      int64
# ENGLISH_SCORE              int64
# READING_SCORE              int64
# MATH_SCORE                 int64
# SOCIAL_SCIENCE_SCORE       int64
# SCHOOL_CALENDAR           object
# PUBLIC_SCHOOL               bool
# BILINGUAL_SCHOOL            bool
# GENDER                    object
# AGE                      float64
# PARENTS_EDUCATION         object
# FAMILY_INCOME_LEVEL       object
# PEOPLE_AT_HOME            object
# FAMILY_HAS_CAR              bool
# HAS_INTERNET_ACCESS         bool
# dtype: object
#
# Missing values in each column:
# ADMISSION                  0
# NATURAL_SCIENCE_SCORE      0
# ENGLISH_SCORE              0
# READING_SCORE              0
# MATH_SCORE                 0
# SOCIAL_SCIENCE_SCORE       0
# SCHOOL_CALENDAR            0
# PUBLIC_SCHOOL              0
# BILINGUAL_SCHOOL           0
# GENDER                     0
# AGE                        0
# PARENTS_EDUCATION        831
# FAMILY_INCOME_LEVEL        0
# PEOPLE_AT_HOME             0
# FAMILY_HAS_CAR             0
# HAS_INTERNET_ACCESS        0
# dtype: int64

# %%
# 2. Summary Statistics:
print("\nSummary statistics for numerical columns:")
print(data.describe())
# Out:
# Summary statistics for numerical columns:
#        NATURAL_SCIENCE_SCORE  ENGLISH_SCORE  READING_SCORE     MATH_SCORE  \
# count          136878.000000  136878.000000  136878.000000  136878.000000
# mean               57.231199      59.650828      58.252436      54.504500
# std                10.216689      13.367733       9.202312      20.038892
# min                20.000000       0.000000       2.000000       0.000000
# 25%                50.000000      50.000000      52.000000      40.000000
# 50%                57.000000      58.000000      58.000000      53.000000
# 75%                64.000000      68.000000      65.000000      68.000000
# max               100.000000     100.000000     100.000000     100.000000
#
#        SOCIAL_SCIENCE_SCORE            AGE
# count         136878.000000  136878.000000
# mean              58.033292      16.862082
# std               10.270291       0.863900
# min               14.000000      15.000000
# 25%               51.000000      16.000000
# 50%               58.000000      17.000000
# 75%               65.000000      17.000000
# max              100.000000      20.000000

# %%
# 3. Visual Exploratory Data Analysis:
data['NATURAL_SCIENCE_SCORE'].hist()
plt.title('Histogram of NATURAL_SCIENCE_SCORE')
plt.xlabel('NATURAL_SCIENCE_SCORE')
plt.ylabel('Frequency')
plt.show()

sns.boxplot(data['NATURAL_SCIENCE_SCORE'])
plt.title('Boxplot of NATURAL_SCIENCE_SCORE')
plt.show()

# %%
# 4. Correlation Analysis:
#correlation_matrix = data.corr()
#plt.figure(figsize=(10,8))
#sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
#plt.title('Correlation Matrix Heatmap')
#plt.show()

# %%
# 5. Advanced EDA:
# We'll use pairplot on a subset of columns for simplicity
#sns.pairplot(data[['age', 'sex', 'bmi', 'bp', 'target']])
#plt.show()

# %%
data["GENDER"][data.GENDER == "F"] = 0
data["GENDER"][data.GENDER == "M"] = 1
data["GENDER"]
# Out:
# C:\Users\hajko\AppData\Local\Temp\ipykernel_16736\4185940202.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data["GENDER"][data.GENDER == "F"] = 0
# C:\Users\hajko\AppData\Local\Temp\ipykernel_16736\4185940202.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["GENDER"][data.GENDER == "F"] = 0
# C:\Users\hajko\AppData\Local\Temp\ipykernel_16736\4185940202.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data["GENDER"][data.GENDER == "M"] = 1
# C:\Users\hajko\AppData\Local\Temp\ipykernel_16736\4185940202.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["GENDER"][data.GENDER == "M"] = 1
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0
#          ..
# 136873    1
# 136874    0
# 136875    1
# 136876    1
# 136877    0
# Name: GENDER, Length: 136878, dtype: object

# %%
numerical= data.select_dtypes(include= ["int64", "float64"])
boolean = data.select_dtypes(include= ["bool"])
categorical = data.select_dtypes(include= ["object"])

print(categorical.head())
# Out:
#   SCHOOL_CALENDAR GENDER PARENTS_EDUCATION FAMILY_INCOME_LEVEL PEOPLE_AT_HOME
# 0               A      0        Vocational                   3         3 or 4
# 1               A      1           Primary                   1             7+
# 2               A      1        University                   3         3 or 4
# 3               A      1        University                   3         3 or 4
# 4               A      0           Primary                   1         3 or 4
